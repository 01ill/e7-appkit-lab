# %%
def flops(count: int) -> None:
    assert count % 8 == 0
    for i in range(0, count//8):
        dst_reg = i % 4
        print(f"vfma.f32 q{dst_reg}, q{(dst_reg-2) % 4}, q{(dst_reg-3) % 4}")

# %%
flops(4*2000)
# Out:
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# vfma.f32 q1, q3, q2
# vfma.f32 q2, q0, q3
# vfma.f32 q3, q1, q0
# vfma.f32 q0, q2, q1
# ...
